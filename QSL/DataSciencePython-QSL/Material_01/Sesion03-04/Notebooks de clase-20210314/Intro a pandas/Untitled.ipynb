# %%
import pandas as pd

# %%
dbz = pd.DataFrame(
    {
        "nombre": ["Goku", "Vegeta"],
        "nombre_saiya": ["Cacaroto", "Vegeta"],
        "edad": [33, 30],
        
    }
)

# %%
dbz
# Out:
#    nombre nombre_saiya  edad
# 0    Goku     Cacaroto    33
# 1  Vegeta       Vegeta    30

# %%
dbz = pd.DataFrame(
    [
     ["Goku", "Cacaroto", 33],
     ["Vegeta", "Vegeta", 39]
    ], columns = ["nombre", "nombre_saiya", "edad"]
)

# %%
dbz
# Out:
#    nombre nombre_saiya  edad
# 0    Goku     Cacaroto    33
# 1  Vegeta       Vegeta    39

# %%
type(dbz)
# Out:
# pandas.core.frame.DataFrame

# %%
votos_primarias_us = pd.read_csv("primary_results.csv")

# %%
votos_primarias_us
# Out:
#          state state_abbreviation                county        fips  \
# 0      Alabama                 AL               Autauga      1001.0
# 1      Alabama                 AL               Autauga      1001.0
# 2      Alabama                 AL               Baldwin      1003.0
# 3      Alabama                 AL               Baldwin      1003.0
# 4      Alabama                 AL               Barbour      1005.0
# 5      Alabama                 AL               Barbour      1005.0
# 6      Alabama                 AL                  Bibb      1007.0
# 7      Alabama                 AL                  Bibb      1007.0
# 8      Alabama                 AL                Blount      1009.0
# 9      Alabama                 AL                Blount      1009.0
# 10     Alabama                 AL               Bullock      1011.0
# 11     Alabama                 AL               Bullock      1011.0
# 12     Alabama                 AL                Butler      1013.0
# 13     Alabama                 AL                Butler      1013.0
# 14     Alabama                 AL               Calhoun      1015.0
# 15     Alabama                 AL               Calhoun      1015.0
# 16     Alabama                 AL              Chambers      1017.0
# 17     Alabama                 AL              Chambers      1017.0
# 18     Alabama                 AL              Cherokee      1019.0
# 19     Alabama                 AL              Cherokee      1019.0
# 20     Alabama                 AL               Chilton      1021.0
# 21     Alabama                 AL               Chilton      1021.0
# 22     Alabama                 AL               Choctaw      1023.0
# 23     Alabama                 AL               Choctaw      1023.0
# 24     Alabama                 AL                Clarke      1025.0
# 25     Alabama                 AL                Clarke      1025.0
# 26     Alabama                 AL                  Clay      1027.0
# 27     Alabama                 AL                  Clay      1027.0
# 28     Alabama                 AL              Cleburne      1029.0
# 29     Alabama                 AL              Cleburne      1029.0
# ...        ...                ...                   ...         ...
# 24581  Wyoming                 WY          Fremont-Park  95600029.0
# 24582  Wyoming                 WY          Fremont-Park  95600029.0
# 24583  Wyoming                 WY         Goshen-Platte  95600035.0
# 24584  Wyoming                 WY         Goshen-Platte  95600035.0
# 24585  Wyoming                 WY         Goshen-Platte  95600035.0
# 24586  Wyoming                 WY         Goshen-Platte  95600035.0
# 24587  Wyoming                 WY  Hot Springs-Washakie  95600030.0
# 24588  Wyoming                 WY  Hot Springs-Washakie  95600030.0
# 24589  Wyoming                 WY  Hot Springs-Washakie  95600030.0
# 24590  Wyoming                 WY  Hot Springs-Washakie  95600030.0
# 24591  Wyoming                 WY               Laramie  95600036.0
# 24592  Wyoming                 WY               Laramie  95600036.0
# 24593  Wyoming                 WY               Laramie  95600036.0
# 24594  Wyoming                 WY               Laramie  95600036.0
# 24595  Wyoming                 WY     Sheridan-Big Horn  95600031.0
# 24596  Wyoming                 WY     Sheridan-Big Horn  95600031.0
# 24597  Wyoming                 WY     Sheridan-Big Horn  95600031.0
# 24598  Wyoming                 WY     Sheridan-Big Horn  95600031.0
# 24599  Wyoming                 WY     Sweetwater-Carbon  95600026.0
# 24600  Wyoming                 WY     Sweetwater-Carbon  95600026.0
# 24601  Wyoming                 WY     Sweetwater-Carbon  95600026.0
# 24602  Wyoming                 WY     Sweetwater-Carbon  95600026.0
# 24603  Wyoming                 WY        Teton-Sublette  95600028.0
# 24604  Wyoming                 WY        Teton-Sublette  95600028.0
# 24605  Wyoming                 WY        Teton-Sublette  95600028.0
# 24606  Wyoming                 WY        Teton-Sublette  95600028.0
# 24607  Wyoming                 WY         Uinta-Lincoln  95600027.0
# 24608  Wyoming                 WY         Uinta-Lincoln  95600027.0
# 24609  Wyoming                 WY         Uinta-Lincoln  95600027.0
# 24610  Wyoming                 WY         Uinta-Lincoln  95600027.0
#
#             party        candidate  votes  fraction_votes
# 0        Democrat   Bernie Sanders    544           0.182
# 1        Democrat  Hillary Clinton   2387           0.800
# 2        Democrat   Bernie Sanders   2694           0.329
# 3        Democrat  Hillary Clinton   5290           0.647
# 4        Democrat   Bernie Sanders    222           0.078
# 5        Democrat  Hillary Clinton   2567           0.906
# 6        Democrat   Bernie Sanders    246           0.197
# 7        Democrat  Hillary Clinton    942           0.755
# 8        Democrat   Bernie Sanders    395           0.386
# 9        Democrat  Hillary Clinton    564           0.551
# 10       Democrat   Bernie Sanders    178           0.066
# 11       Democrat  Hillary Clinton   2451           0.913
# 12       Democrat   Bernie Sanders    156           0.065
# 13       Democrat  Hillary Clinton   2196           0.921
# 14       Democrat   Bernie Sanders   1425           0.218
# 15       Democrat  Hillary Clinton   5011           0.765
# 16       Democrat   Bernie Sanders    312           0.095
# 17       Democrat  Hillary Clinton   2899           0.886
# 18       Democrat   Bernie Sanders    268           0.249
# 19       Democrat  Hillary Clinton    712           0.661
# 20       Democrat   Bernie Sanders    289           0.246
# 21       Democrat  Hillary Clinton    860           0.731
# 22       Democrat   Bernie Sanders    273           0.124
# 23       Democrat  Hillary Clinton   1772           0.802
# 24       Democrat   Bernie Sanders    213           0.063
# 25       Democrat  Hillary Clinton   3148           0.930
# 26       Democrat   Bernie Sanders    135           0.137
# 27       Democrat  Hillary Clinton    807           0.818
# 28       Democrat   Bernie Sanders     72           0.238
# 29       Democrat  Hillary Clinton    221           0.732
# ...           ...              ...    ...             ...
# 24581  Republican      Marco Rubio      0           0.000
# 24582  Republican         Ted Cruz     64           0.660
# 24583  Republican     Donald Trump      0           0.000
# 24584  Republican      John Kasich      0           0.000
# 24585  Republican      Marco Rubio      0           0.000
# 24586  Republican         Ted Cruz     83           1.000
# 24587  Republican     Donald Trump      0           0.000
# 24588  Republican      John Kasich      0           0.000
# 24589  Republican      Marco Rubio      0           0.000
# 24590  Republican         Ted Cruz     43           1.000
# 24591  Republican     Donald Trump      0           0.000
# 24592  Republican      John Kasich      0           0.000
# 24593  Republican      Marco Rubio     38           0.176
# 24594  Republican         Ted Cruz    141           0.653
# 24595  Republican     Donald Trump      0           0.000
# 24596  Republican      John Kasich      0           0.000
# 24597  Republican      Marco Rubio     30           0.400
# 24598  Republican         Ted Cruz     45           0.600
# 24599  Republican     Donald Trump     16           0.180
# 24600  Republican      John Kasich      0           0.000
# 24601  Republican      Marco Rubio     28           0.315
# 24602  Republican         Ted Cruz     45           0.506
# 24603  Republican     Donald Trump     21           0.525
# 24604  Republican      John Kasich      0           0.000
# 24605  Republican      Marco Rubio     19           0.475
# 24606  Republican         Ted Cruz      0           0.000
# 24607  Republican     Donald Trump      0           0.000
# 24608  Republican      John Kasich      0           0.000
# 24609  Republican      Marco Rubio      0           0.000
# 24610  Republican         Ted Cruz     53           1.000
#
# [24611 rows x 8 columns]

# %%
df = votos_primarias_us

# %%
df.shape
# Out:
# (24611, 8)

# %%
df.head(10)
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
# 5  Alabama                 AL  Barbour  1005.0  Democrat  Hillary Clinton
# 6  Alabama                 AL     Bibb  1007.0  Democrat   Bernie Sanders
# 7  Alabama                 AL     Bibb  1007.0  Democrat  Hillary Clinton
# 8  Alabama                 AL   Blount  1009.0  Democrat   Bernie Sanders
# 9  Alabama                 AL   Blount  1009.0  Democrat  Hillary Clinton
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078
# 5   2567           0.906
# 6    246           0.197
# 7    942           0.755
# 8    395           0.386
# 9    564           0.551

# %%
df.tail(10)
# Out:
#          state state_abbreviation             county        fips       party  \
# 24601  Wyoming                 WY  Sweetwater-Carbon  95600026.0  Republican
# 24602  Wyoming                 WY  Sweetwater-Carbon  95600026.0  Republican
# 24603  Wyoming                 WY     Teton-Sublette  95600028.0  Republican
# 24604  Wyoming                 WY     Teton-Sublette  95600028.0  Republican
# 24605  Wyoming                 WY     Teton-Sublette  95600028.0  Republican
# 24606  Wyoming                 WY     Teton-Sublette  95600028.0  Republican
# 24607  Wyoming                 WY      Uinta-Lincoln  95600027.0  Republican
# 24608  Wyoming                 WY      Uinta-Lincoln  95600027.0  Republican
# 24609  Wyoming                 WY      Uinta-Lincoln  95600027.0  Republican
# 24610  Wyoming                 WY      Uinta-Lincoln  95600027.0  Republican
#
#           candidate  votes  fraction_votes
# 24601   Marco Rubio     28           0.315
# 24602      Ted Cruz     45           0.506
# 24603  Donald Trump     21           0.525
# 24604   John Kasich      0           0.000
# 24605   Marco Rubio     19           0.475
# 24606      Ted Cruz      0           0.000
# 24607  Donald Trump      0           0.000
# 24608   John Kasich      0           0.000
# 24609   Marco Rubio      0           0.000
# 24610      Ted Cruz     53           1.000

# %%
df.dtypes
# Out:
# state                  object
# state_abbreviation     object
# county                 object
# fips                  float64
# party                  object
# candidate              object
# votes                   int64
# fraction_votes        float64
# dtype: object

# %%
df.describe()
# Out:
#                fips          votes  fraction_votes
# count  2.451100e+04   24611.000000    24611.000000
# mean   2.667152e+07    2306.252773        0.304524
# std    4.200978e+07    9861.183572        0.231401
# min    1.001000e+03       0.000000        0.000000
# 25%    2.109100e+04      68.000000        0.094000
# 50%    4.208100e+04     358.000000        0.273000
# 75%    9.090012e+07    1375.000000        0.479000
# max    9.560004e+07  590502.000000        1.000000

# %%
df.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
df.index
# Out:
# RangeIndex(start=0, stop=24611, step=1)

# %%
df.loc[0]
# Out:
# state                        Alabama
# state_abbreviation                AL
# county                       Autauga
# fips                            1001
# party                       Democrat
# candidate             Bernie Sanders
# votes                            544
# fraction_votes                 0.182
# Name: 0, dtype: object

# %%
df2 = df.set_index("county")

# %%
df2.head()
# Out:
#            state state_abbreviation    fips     party        candidate  votes  \
# county
# Autauga  Alabama                 AL  1001.0  Democrat   Bernie Sanders    544
# Autauga  Alabama                 AL  1001.0  Democrat  Hillary Clinton   2387
# Baldwin  Alabama                 AL  1003.0  Democrat   Bernie Sanders   2694
# Baldwin  Alabama                 AL  1003.0  Democrat  Hillary Clinton   5290
# Barbour  Alabama                 AL  1005.0  Democrat   Bernie Sanders    222
#
#          fraction_votes
# county
# Autauga           0.182
# Autauga           0.800
# Baldwin           0.329
# Baldwin           0.647
# Barbour           0.078

# %%
df2.loc["Baldwin"]
# Out:
#            state state_abbreviation        fips       party        candidate  \
# county
# Baldwin  Alabama                 AL      1003.0    Democrat   Bernie Sanders
# Baldwin  Alabama                 AL      1003.0    Democrat  Hillary Clinton
# Baldwin  Alabama                 AL      1003.0  Republican       Ben Carson
# Baldwin  Alabama                 AL      1003.0  Republican     Donald Trump
# Baldwin  Alabama                 AL      1003.0  Republican      John Kasich
# Baldwin  Alabama                 AL      1003.0  Republican      Marco Rubio
# Baldwin  Alabama                 AL      1003.0  Republican         Ted Cruz
# Baldwin  Georgia                 GA     13009.0    Democrat   Bernie Sanders
# Baldwin  Georgia                 GA     13009.0    Democrat  Hillary Clinton
# Baldwin  Georgia                 GA     13009.0  Republican       Ben Carson
# Baldwin  Georgia                 GA     13009.0  Republican     Donald Trump
# Baldwin  Georgia                 GA     13009.0  Republican      John Kasich
# Baldwin  Georgia                 GA     13009.0  Republican      Marco Rubio
# Baldwin  Georgia                 GA     13009.0  Republican         Ted Cruz
# Baldwin    Maine                 ME  92300026.0    Democrat   Bernie Sanders
# Baldwin    Maine                 ME  92300026.0    Democrat  Hillary Clinton
#
#          votes  fraction_votes
# county
# Baldwin   2694           0.329
# Baldwin   5290           0.647
# Baldwin   4221           0.084
# Baldwin  23618           0.469
# Baldwin   2987           0.059
# Baldwin   9703           0.193
# Baldwin   8571           0.170
# Baldwin    762           0.199
# Baldwin   3034           0.794
# Baldwin    350           0.077
# Baldwin   2069           0.458
# Baldwin    184           0.041
# Baldwin    961           0.213
# Baldwin    880           0.195
# Baldwin      2           0.667
# Baldwin      1           0.333

# %%
df2.iloc[100]
# Out:
# state                        Alabama
# state_abbreviation                AL
# fips                            1101
# party                       Democrat
# candidate             Bernie Sanders
# votes                           4266
# fraction_votes                 0.128
# Name: Montgomery, dtype: object

# %%
df["state"][:3]
# Out:
# 0    Alabama
# 1    Alabama
# 2    Alabama
# Name: state, dtype: object

# %%
df.state[:3]
# Out:
# 0    Alabama
# 1    Alabama
# 2    Alabama
# Name: state, dtype: object

# %%
df["shape"] = 666

# %%
df.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes  shape
# 0    544           0.182    666
# 1   2387           0.800    666
# 2   2694           0.329    666
# 3   5290           0.647    666
# 4    222           0.078    666

# %%
df.shape
# Out:
# (24611, 9)

# %%
type(df["county"])
# Out:
# pandas.core.series.Series

# %%
type(df[["county", "candidate"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#                fips          votes  fraction_votes    shape
# count  2.451100e+04   24611.000000    24611.000000  24611.0
# mean   2.667152e+07    2306.252773        0.304524    666.0
# std    4.200978e+07    9861.183572        0.231401      0.0
# min    1.001000e+03       0.000000        0.000000    666.0
# 25%    2.109100e+04      68.000000        0.094000    666.0
# 50%    4.208100e+04     358.000000        0.273000    666.0
# 75%    9.090012e+07    1375.000000        0.479000    666.0
# max    9.560004e+07  590502.000000        1.000000    666.0

# %%
df[df.votes>=590502]
# Out:
#            state state_abbreviation       county    fips     party  \
# 1386  California                 CA  Los Angeles  6037.0  Democrat
#
#             candidate   votes  fraction_votes  shape
# 1386  Hillary Clinton  590502            0.57    666

# %%
df[(df.county == "Manhattan") & (df.party == "Republican")]
# Out:
#           state state_abbreviation     county     fips       party  \
# 15162  New York                 NY  Manhattan  36061.0  Republican
# 15163  New York                 NY  Manhattan  36061.0  Republican
# 15164  New York                 NY  Manhattan  36061.0  Republican
#
#           candidate  votes  fraction_votes  shape
# 15162  Donald Trump  10393           0.418    666
# 15163   John Kasich  11251           0.452    666
# 15164      Ted Cruz   3243           0.130    666

# %%
df.query("county=='Manhattan' and party=='Republican'")
# Out:
#           state state_abbreviation     county     fips       party  \
# 15162  New York                 NY  Manhattan  36061.0  Republican
# 15163  New York                 NY  Manhattan  36061.0  Republican
# 15164  New York                 NY  Manhattan  36061.0  Republican
#
#           candidate  votes  fraction_votes  shape
# 15162  Donald Trump  10393           0.418    666
# 15163   John Kasich  11251           0.452    666
# 15164      Ted Cruz   3243           0.130    666

# %%
df_sorted = df.sort_values(by="votes", ascending=False)

# %%
df_sorted.head()
# Out:
#            state state_abbreviation        county        fips     party  \
# 1386  California                 CA   Los Angeles      6037.0  Democrat
# 1385  California                 CA   Los Angeles      6037.0  Democrat
# 4451    Illinois                 IL       Chicago  91700103.0  Democrat
# 4450    Illinois                 IL       Chicago  91700103.0  Democrat
# 4463    Illinois                 IL  Cook Suburbs  91700104.0  Democrat
#
#             candidate   votes  fraction_votes  shape
# 1386  Hillary Clinton  590502           0.570    666
# 1385   Bernie Sanders  434656           0.420    666
# 4451  Hillary Clinton  366954           0.536    666
# 4450   Bernie Sanders  311225           0.454    666
# 4463  Hillary Clinton  249217           0.536    666

# %%
df.groupby(["state", "party"])

# %%
df.groupby(["state", "party"])["votes"].sum()
# Out:
# state           party
# Alabama         Democrat       386327
#                 Republican     837632
# Alaska          Democrat          539
#                 Republican      21930
# Arizona         Democrat       399097
#                 Republican     435103
# Arkansas        Democrat       209448
#                 Republican     396523
# California      Democrat      3442623
#                 Republican    1495574
# Colorado        Democrat       121184
# Connecticut     Democrat       322485
#                 Republican     208817
# Delaware        Democrat        92609
#                 Republican      67807
# Florida         Democrat      1664003
#                 Republican    2276926
# Georgia         Democrat       757340
#                 Republican    1275601
# Hawaii          Democrat        33658
#                 Republican      13228
# Idaho           Democrat        23705
#                 Republican     215284
# Illinois        Democrat      1987834
#                 Republican    1384703
# Indiana         Democrat       638638
#                 Republican    1080653
# Iowa            Democrat       139980
#                 Republican     186724
# Kansas          Democrat        39043
#                                ...
# Oklahoma        Democrat       313392
#                 Republican     452731
# Oregon          Democrat       572485
#                 Republican     361490
# Pennsylvania    Democrat      1638644
#                 Republican    1537696
# Rhode Island    Democrat       119213
#                 Republican      60381
# South Carolina  Democrat       367491
#                 Republican     737917
# South Dakota    Democrat        53004
#                 Republican      66877
# Tennessee       Democrat       365637
#                 Republican     834939
# Texas           Democrat      1410641
#                 Republican    2737248
# Utah            Democrat        76999
#                 Republican     177204
# Vermont         Democrat       134198
#                 Republican      58762
# Virginia        Democrat       778865
#                 Republican    1012807
# Washington      Democrat        26299
#                 Republican     510851
# West Virginia   Democrat       210214
#                 Republican     188138
# Wisconsin       Democrat      1000703
#                 Republican    1072699
# Wyoming         Democrat          280
#                 Republican        903
# Name: votes, Length: 95, dtype: int64

# %%
df["letra_inicial"]=df.state_abbreviation.apply(lambda s: s[0])

# %%
df.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes  shape letra_inicial
# 0    544           0.182    666             A
# 1   2387           0.800    666             A
# 2   2694           0.329    666             A
# 3   5290           0.647    666             A
# 4    222           0.078    666             A

# %%
df.groupby("letra_inicial")["votes"].sum().sort_values()
# Out:
# letra_inicial
# H      46886
# D     160416
# R     179594
# U     254203
# L     585781
# K     760181
# S    1225289
# V    1984632
# G    2032941
# A    2686599
# W    3010087
# P    3176340
# F    3940929
# O    4904270
# T    5348465
# C    5590683
# I    5657521
# N    7329864
# M    7884506
# Name: votes, dtype: int64

# %%
df_pobreza = pd.read_csv("PovertyEstimates.csv")

# %%
df_pobreza.head()
# Out:
#    FIPStxt  PCTPOVALL_2015
# 0        0            14.7
# 1     1000            18.5
# 2     1001            12.7
# 3     1003            12.9
# 4     1005            32.0

# %%
df=df.merge(df_pobreza, left_on="fips", right_on="FIPStxt")

# %%
df.head()
# Out:
#      state state_abbreviation   county    fips       party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0    Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0    Democrat  Hillary Clinton
# 2  Alabama                 AL  Autauga  1001.0  Republican       Ben Carson
# 3  Alabama                 AL  Autauga  1001.0  Republican     Donald Trump
# 4  Alabama                 AL  Autauga  1001.0  Republican      John Kasich
#
#    votes  fraction_votes  shape letra_inicial  FIPStxt  PCTPOVALL_2015
# 0    544           0.182    666             A     1001            12.7
# 1   2387           0.800    666             A     1001            12.7
# 2   1764           0.146    666             A     1001            12.7
# 3   5387           0.445    666             A     1001            12.7
# 4    421           0.035    666             A     1001            12.7

# %%
df.groupby(["county", "party"]).agg({
    "PCTPOVALL_2015": "count",
    "fraction_votes": "max"
})
# Out:
#                         PCTPOVALL_2015  fraction_votes
# county      party
# Abbeville   Democrat                 2           0.818
#             Republican               6           0.369
# Acadia      Democrat                 2           0.537
#             Republican               4           0.445
# Accomack    Democrat                 2           0.720
#             Republican               5           0.479
# Ada         Democrat                 2           0.805
#             Republican               4           0.403
# Adair       Democrat                10           0.588
#             Republican              24           0.578
# Adams       Democrat                24           0.867
#             Republican              42           0.790
# Aiken       Democrat                 2           0.702
#             Republican               6           0.316
# Alachua     Democrat                 2           0.492
#             Republican               4           0.382
# Alamance    Democrat                 2           0.537
#             Republican               4           0.409
# Alameda     Democrat                 2           0.537
#             Republican               3           0.669
# Alamosa     Democrat                 2           0.630
# Albany      Democrat                 4           0.758
#             Republican               3           0.481
# Albemarle   Democrat                 2           0.545
#             Republican               5           0.371
# Alcona      Democrat                 2           0.487
#             Republican               4           0.518
# Alcorn      Democrat                 2           0.708
#             Republican               4           0.504
# Alexander   Democrat                 4           0.600
# ...                                ...             ...
# Yankton     Democrat                 2           0.549
#             Republican               3           0.636
# Yates       Democrat                 2           0.548
#             Republican               3           0.526
# Yavapai     Democrat                 2           0.529
#             Republican               3           0.476
# Yazoo       Democrat                 2           0.908
#             Republican               4           0.548
# Yell        Democrat                 2           0.582
#             Republican               5           0.376
# Yellowstone Democrat                 2           0.502
#             Republican               3           0.712
# Yoakum      Democrat                 2           0.476
#             Republican               5           0.439
# Yolo        Democrat                 2           0.518
#             Republican               3           0.723
# York        Democrat                 8           0.670
#             Republican              17           0.599
# Young       Democrat                 2           0.586
#             Republican               5           0.463
# Yuba        Democrat                 2           0.511
#             Republican               3           0.828
# Yuma        Democrat                 4           0.637
#             Republican               3           0.495
# Zapata      Democrat                 2           0.678
#             Republican               5           0.395
# Zavala      Democrat                 2           0.755
#             Republican               5           0.000
# Ziebach     Democrat                 2           0.589
#             Republican               3           0.687
#
# [3267 rows x 2 columns]
